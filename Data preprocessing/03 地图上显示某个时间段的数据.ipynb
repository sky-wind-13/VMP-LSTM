# %% [markdown]
# ### 02_aisdk_2023_02_08_091

# %%
import pandas as pd
import folium
import random

# 读取CSV文件
df = pd.read_csv('02_aisdk_2023_02_08_091.csv', usecols=['Timestamp', 'MMSI', 'Latitude', 'Longitude'])

# 根据MMSI进行分组
grouped = df.groupby('MMSI')

# 创建地图
m = folium.Map(location=[df['Latitude'].mean(), df['Longitude'].mean()], zoom_start=10)

# 为每个组添加标记
for name, group in grouped:
    color = '#' + ''.join([random.choice('0123456789ABCDEF') for j in range(6)])
    for lat, lon, in zip(group['Latitude'], group['Longitude']):
        folium.Marker(location=[lat, lon], icon=folium.Icon(color=color)).add_to(m)

# 保存地图
m.save('03_aisdk_2023_02_08_091.html')
# Out:
# C:\Users\28065\AppData\Local\Temp\ipykernel_7260\422001757.py:18: UserWarning: color argument of Icon should be one of: {'blue', 'lightgray', 'darkpurple', 'white', 'red', 'pink', 'darkblue', 'lightred', 'green', 'lightgreen', 'purple', 'orange', 'gray', 'beige', 'black', 'cadetblue', 'lightblue', 'darkgreen', 'darkred'}.
#   folium.Marker(location=[lat, lon], icon=folium.Icon(color=color)).add_to(m)

# %% [markdown]
# ### 02_aisdk_2023_02_08_101

# %%
import pandas as pd
import folium
import random

# 读取CSV文件
df = pd.read_csv('02_aisdk_2023_02_08_101.csv', usecols=['Timestamp', 'MMSI', 'Latitude', 'Longitude'])

# 根据MMSI进行分组
grouped = df.groupby('MMSI')

# 创建地图
m = folium.Map(location=[df['Latitude'].mean(), df['Longitude'].mean()], zoom_start=10)

# 为每个组添加标记
for name, group in grouped:
    color = '#' + ''.join([random.choice('0123456789ABCDEF') for j in range(6)])
    for lat, lon, in zip(group['Latitude'], group['Longitude']):
        folium.Marker(location=[lat, lon], icon=folium.Icon(color=color)).add_to(m)

# 保存地图
m.save('03_aisdk_2023_02_08_101.html')
# Out:
# C:\Users\28065\AppData\Local\Temp\ipykernel_1204\2779683169.py:18: UserWarning: color argument of Icon should be one of: {'purple', 'black', 'darkpurple', 'lightgreen', 'blue', 'darkblue', 'cadetblue', 'orange', 'beige', 'green', 'white', 'pink', 'red', 'lightred', 'darkred', 'lightblue', 'darkgreen', 'gray', 'lightgray'}.
#   folium.Marker(location=[lat, lon], icon=folium.Icon(color=color)).add_to(m)

# %% [markdown]
# ## 02_aisdk_2023_02_08_111

# %%
import pandas as pd
import folium
import random

# 读取CSV文件
df = pd.read_csv('02_aisdk_2023_02_08_111.csv', usecols=['Timestamp', 'MMSI', 'Latitude', 'Longitude'])

# 根据MMSI进行分组
grouped = df.groupby('MMSI')

# 创建地图
m = folium.Map(location=[df['Latitude'].mean(), df['Longitude'].mean()], zoom_start=10)

# 为每个组添加标记
for name, group in grouped:
    color = '#' + ''.join([random.choice('0123456789ABCDEF') for j in range(6)])
    for lat, lon, in zip(group['Latitude'], group['Longitude']):
        folium.Marker(location=[lat, lon], icon=folium.Icon(color=color)).add_to(m)

# 保存地图
m.save('03_aisdk_2023_02_08_111.html')
# Out:
# C:\Users\28065\AppData\Local\Temp\ipykernel_1204\3727272571.py:18: UserWarning: color argument of Icon should be one of: {'purple', 'black', 'darkpurple', 'lightgreen', 'blue', 'darkblue', 'cadetblue', 'orange', 'beige', 'green', 'white', 'pink', 'red', 'lightred', 'darkred', 'lightblue', 'darkgreen', 'gray', 'lightgray'}.
#   folium.Marker(location=[lat, lon], icon=folium.Icon(color=color)).add_to(m)

# %% [markdown]
# ### 02_aisdk_2023_02_08_121

# %%
import pandas as pd
import folium
import random

# 读取CSV文件
df = pd.read_csv('02_aisdk_2023_02_08_121.csv', usecols=['Timestamp', 'MMSI', 'Latitude', 'Longitude'])

# 根据MMSI进行分组
grouped = df.groupby('MMSI')

# 创建地图
m = folium.Map(location=[df['Latitude'].mean(), df['Longitude'].mean()], zoom_start=10)

# 为每个组添加标记
for name, group in grouped:
    color = '#' + ''.join([random.choice('0123456789ABCDEF') for j in range(6)])
    for lat, lon, in zip(group['Latitude'], group['Longitude']):
        folium.Marker(location=[lat, lon], icon=folium.Icon(color=color)).add_to(m)

# 保存地图
m.save('03_aisdk_2023_02_08_121.html')
# Out:
# C:\Users\28065\AppData\Local\Temp\ipykernel_1204\1390814648.py:18: UserWarning: color argument of Icon should be one of: {'purple', 'black', 'darkpurple', 'lightgreen', 'blue', 'darkblue', 'cadetblue', 'orange', 'beige', 'green', 'white', 'pink', 'red', 'lightred', 'darkred', 'lightblue', 'darkgreen', 'gray', 'lightgray'}.
#   folium.Marker(location=[lat, lon], icon=folium.Icon(color=color)).add_to(m)

# %% [markdown]
# ## 02_aisdk_2023_02_08_141

# %%
import pandas as pd
import folium
import random

# 读取CSV文件
df = pd.read_csv('02_aisdk_2023_02_08_141.csv', usecols=['Timestamp', 'MMSI', 'Latitude', 'Longitude'])

# 根据MMSI进行分组
grouped = df.groupby('MMSI')

# 创建地图
m = folium.Map(location=[df['Latitude'].mean(), df['Longitude'].mean()], zoom_start=10)

# 为每个组添加标记
for name, group in grouped:
    color = '#' + ''.join([random.choice('0123456789ABCDEF') for j in range(6)])
    for lat, lon, in zip(group['Latitude'], group['Longitude']):
        folium.Marker(location=[lat, lon], icon=folium.Icon(color=color)).add_to(m)

# 保存地图
m.save('03_aisdk_2023_02_08_141.html')
# Out:
# C:\Users\28065\AppData\Local\Temp\ipykernel_1988\1310109478.py:18: UserWarning: color argument of Icon should be one of: {'beige', 'white', 'black', 'red', 'blue', 'orange', 'pink', 'darkpurple', 'purple', 'green', 'darkred', 'cadetblue', 'lightgreen', 'gray', 'darkblue', 'lightgray', 'lightblue', 'lightred', 'darkgreen'}.
#   folium.Marker(location=[lat, lon], icon=folium.Icon(color=color)).add_to(m)
